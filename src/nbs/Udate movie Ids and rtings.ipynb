# %%
import setup_django
setup_django.init()

# %%
import pandas as pd
from django.conf import settings
from ratings.models import Rating
from movies.models import Movie

LINKS_SMALL_CSV = settings.DATA_DIR / 'links_small.csv'
LINKS_SMALL_CSV.exists()
# Out:
# True

# %%
qs = Rating.objects.all()
missing_movie_ids = []
for instance in qs:
    if instance.content_object is None:
        missing_movie_ids.append(instance.object_id)

_total = len(missing_movie_ids)
total_missing = list(set(missing_movie_ids))

# %%
print(len(total_missing), _total)
# Out:
# 6397 57213

# %%
links_df = pd.read_csv(LINKS_SMALL_CSV)
links_df.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
ms_df = links_df.copy()[links_df.movieId.isin(total_missing)]
ms_df.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 3        4  114885  31357.0
# 6        7  114319  11860.0
# 7        8  112302  45325.0
# 8        9  114576   9091.0

# %%
ms_df.shape[0] == len(total_missing)
# Out:
# True

# %%
def enrich_imdb_col(val):
    val = str(val)
    if len(val) == 7:
        val = f"tt{val}"
        return val
    if len(val) == 6:
        val = f"tt0{val}"
        return val
    if len(val) == 5:
        val = f"tt00{val}"
        return val
    return val

# %%
ms_df['tt'] = ms_df['imdbId'].apply(enrich_imdb_col)

ms_df.head()
# Out:
#    movieId  imdbId   tmdbId         tt
# 0        1  114709    862.0  tt0114709
# 3        4  114885  31357.0  tt0114885
# 6        7  114319  11860.0  tt0114319
# 7        8  112302  45325.0  tt0112302
# 8        9  114576   9091.0  tt0114576

# %%
MOVIES_CSV = settings.DATA_DIR / 'movies_metadata.csv'
MOVIES_CSV.exists()
# Out:
# True

# %%
movies_cols = ['title','overview','release_date','imdb_id']
movies_df = pd.read_csv(MOVIES_CSV, usecols=movies_cols)
movies_df.head()
# Out:
#      imdb_id                                           overview release_date  \
# 0  tt0114709  Led by Woody, Andy's toys live happily in his ...   1995-10-30
# 1  tt0113497  When siblings Judy and Peter discover an encha...   1995-12-15
# 2  tt0113228  A family wedding reignites the ancient feud be...   1995-12-22
# 3  tt0114885  Cheated on, mistreated and stepped on, the wom...   1995-12-22
# 4  tt0113041  Just when George Banks has recovered from his ...   1995-02-10
#
#                          title
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II

# %%
missing_movies_df = ms_df.merge(movies_df, left_on='tt', right_on='imdb_id')

missing_movies_df.head()
# Out:
#    movieId  imdbId   tmdbId         tt    imdb_id  \
# 0        1  114709    862.0  tt0114709  tt0114709
# 1        4  114885  31357.0  tt0114885  tt0114885
# 2        7  114319  11860.0  tt0114319  tt0114319
# 3        8  112302  45325.0  tt0112302  tt0112302
# 4        9  114576   9091.0  tt0114576  tt0114576
#
#                                             overview release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...   1995-10-30
# 1  Cheated on, mistreated and stepped on, the wom...   1995-12-22
# 2  An ugly duckling having undergone a remarkable...   1995-12-15
# 3  A mischievous young boy, Tom Sawyer, witnesses...   1995-12-22
# 4  International action superstar Jean Claude Van...   1995-12-22
#
#                title
# 0          Toy Story
# 1  Waiting to Exhale
# 2            Sabrina
# 3       Tom and Huck
# 4       Sudden Death

# %%
missing_movies_df['id'] = missing_movies_df['movieId']
missing_movies_df['id_alt'] = missing_movies_df['tmdbId'].apply(lambda x: str(int(x)))

# %%
missing_movies_df.head()
# Out:
#    movieId  imdbId   tmdbId         tt    imdb_id  \
# 0        1  114709    862.0  tt0114709  tt0114709
# 1        4  114885  31357.0  tt0114885  tt0114885
# 2        7  114319  11860.0  tt0114319  tt0114319
# 3        8  112302  45325.0  tt0112302  tt0112302
# 4        9  114576   9091.0  tt0114576  tt0114576
#
#                                             overview release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...   1995-10-30
# 1  Cheated on, mistreated and stepped on, the wom...   1995-12-22
# 2  An ugly duckling having undergone a remarkable...   1995-12-15
# 3  A mischievous young boy, Tom Sawyer, witnesses...   1995-12-22
# 4  International action superstar Jean Claude Van...   1995-12-22
#
#                title  id id_alt
# 0          Toy Story   1    862
# 1  Waiting to Exhale   4  31357
# 2            Sabrina   7  11860
# 3       Tom and Huck   8  45325
# 4       Sudden Death   9   9091

# %%
final_df = missing_movies_df.copy()[['id', 'id_alt','title']]
final_df['id_alt'] = final_df['id_alt'].astype(str)

# %%
final_df.head()
# Out:
#    id id_alt              title
# 0   1    862          Toy Story
# 1   4  31357  Waiting to Exhale
# 2   7  11860            Sabrina
# 3   8  45325       Tom and Huck
# 4   9   9091       Sudden Death

# %%
alt_id_list = final_df['id_alt'].to_list()

# %%
movies_qs = Movie.objects.filter(id__in=alt_id_list)

# %%
movies_qs
# Out:
# <MovieQuerySet [<Movie: Ariel (1988)>, <Movie: Judgment Night (1993)>, <Movie: Finding Nemo (2003)>, <Movie: Forrest Gump (1994)>, <Movie: American Beauty (1999)>, <Movie: Citizen Kane (1941)>, <Movie: Dancer in the Dark (2000)>, <Movie: The Fifth Element (1997)>, <Movie: My Life Without Me (2003)>, <Movie: The Endless Summer (1966)>, <Movie: Pirates of the Caribbean: The Curse of the Black Pearl (2003)>, <Movie: Kill Bill: Vol. 1 (2003)>, <Movie: Jarhead (2005)>, <Movie: Walk on Water (2004)>, <Movie: Apocalypse Now (1979)>, <Movie: Eternal Sunshine of the Spotless Mind (2004)>, <Movie: A History of Violence (2005)>, <Movie: Twelve Monkeys (1995)>, <Movie: Talk to Her (2002)>, <Movie: 8 Mile (2002)>, '...(remaining elements truncated)...']>

# %%
movies_qs.count()
# Out:
# 6039

# %%
from django.forms.models import model_to_dict

# %%
movies_qs = Movie.objects.filter(id__in=alt_id_list)
for obj in movies_qs:
    data = final_df.copy()[final_df['id_alt'] == str(obj.id)]

    if data.shape[0] == 1:
        og_model_data = model_to_dict(obj)
        update_data = data.to_dict('records')[0]
        if obj.title == update_data.get('title'):
            print(og_model_data)
            og_model_data['id'] = update_data['id']
            new_model_data = {**og_model_data}
            print(new_model_data)
            obj.delete()
            Movie.objects.create(**new_model_data)
# Out:
# {'id': 6, 'title': 'Judgment Night', 'overview': 'While racing to a boxing match, Frank, Mike, John and Rey get more than they bargained for. A wrong turn lands them directly in the path of Fallon, a vicious, wise-cracking drug lord. After accidentally witnessing Fallon murder a disloyal henchman, the four become his unwilling prey in a savage game of cat &amp; mouse as they are mercilessly stalked through the urban jungle in this taut suspense drama', 'release_date': datetime.date(1993, 10, 15), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 31, 919273, tzinfo=datetime.timezone.utc), 'rating_count': 104, 'rating_avg': Decimal('3.95')}
# {'id': 479, 'title': 'Judgment Night', 'overview': 'While racing to a boxing match, Frank, Mike, John and Rey get more than they bargained for. A wrong turn lands them directly in the path of Fallon, a vicious, wise-cracking drug lord. After accidentally witnessing Fallon murder a disloyal henchman, the four become his unwilling prey in a savage game of cat &amp; mouse as they are mercilessly stalked through the urban jungle in this taut suspense drama', 'release_date': datetime.date(1993, 10, 15), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 31, 919273, tzinfo=datetime.timezone.utc), 'rating_count': 104, 'rating_avg': Decimal('3.95')}
# {'id': 12, 'title': 'Finding Nemo', 'overview': "Nemo, an adventurous young clownfish, is unexpectedly taken from his Great Barrier Reef home to a dentist's office aquarium. It's up to his worrisome father Marlin and a friendly but forgetful fish Dory to bring Nemo home -- meeting vegetarian sharks, surfer dude turtles, hypnotic jellyfish, hungry seagulls, and more along the way.", 'release_date': datetime.date(2003, 5, 30), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 31, 924016, tzinfo=datetime.timezone.utc), 'rating_count': 18, 'rating_avg': Decimal('2.89')}
# {'id': 6377, 'title': 'Finding Nemo', 'overview': "Nemo, an adventurous young clownfish, is unexpectedly taken from his Great Barrier Reef home to a dentist's office aquarium. It's up to his worrisome father Marlin and a friendly but forgetful fish Dory to bring Nemo home -- meeting vegetarian sharks, surfer dude turtles, hypnotic jellyfish, hungry seagulls, and more along the way.", 'release_date': datetime.date(2003, 5, 30), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 31, 924016, tzinfo=datetime.timezone.utc), 'rating_count': 18, 'rating_avg': Decimal('2.89')}
# {'id': 13, 'title': 'Forrest Gump', 'overview': "A man with a low IQ has accomplished great things in his life and been present during significant historic events - in each case, far exceeding what anyone imagined he could do. Yet, despite all the things he has attained, his one true love eludes him. 'Forrest Gump' is the story of a man who rose above his challenges, and who proved that determination, courage, and love are more important than ability.", 'release_date': datetime.date(1994, 7, 6), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 31, 925785, tzinfo=datetime.timezone.utc), 'rating_count': 8, 'rating_avg': Decimal('4.12')}
# {'id': 356, 'title': 'Forrest Gump', 'overview': "A man with a low IQ has accomplished great things in his life and been present during significant historic events - in each case, far exceeding what anyone imagined he could do. Yet, despite all the things he has attained, his one true love eludes him. 'Forrest Gump' is the story of a man who rose above his challenges, and who proved that determination, courage, and love are more important than ability.", 'release_date': datetime.date(1994, 7, 6), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 31, 925785, tzinfo=datetime.timezone.utc), 'rating_count': 8, 'rating_avg': Decimal('4.12')}
# {'id': 14, 'title': 'American Beauty', 'overview': "Lester Burnham, a depressed suburban father in a mid-life crisis, decides to turn his hectic life around after developing an infatuation with his daughter's attractive friend.", 'release_date': datetime.date(1999, 9, 15), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 31, 927470, tzinfo=datetime.timezone.utc), 'rating_count': 31, 'rating_avg': Decimal('3.48')}
# {'id': 2858, 'title': 'American Beauty', 'overview': "Lester Burnham, a depressed suburban father in a mid-life crisis, decides to turn his hectic life around after developing an infatuation with his daughter's attractive friend.", 'release_date': datetime.date(1999, 9, 15), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 31, 927470, tzinfo=datetime.timezone.utc), 'rating_count': 31, 'rating_avg': Decimal('3.48')}
# {'id': 15, 'title': 'Citizen Kane', 'overview': 'Newspaper magnate, Charles Foster Kane is taken from his mother as a boy and made the ward of a rich industrialist. As a result, every well-meaning, tyrannical or self-destructive move he makes for the rest of his life appears in some way to be a reaction to that deeply wounding event.', 'release_date': datetime.date(1941, 4, 30), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 31, 929254, tzinfo=datetime.timezone.utc), 'rating_count': 11, 'rating_avg': Decimal('2.36')}
# {'id': 923, 'title': 'Citizen Kane', 'overview': 'Newspaper magnate, Charles Foster Kane is taken from his mother as a boy and made the ward of a rich industrialist. As a result, every well-meaning, tyrannical or self-destructive move he makes for the rest of his life appears in some way to be a reaction to that deeply wounding event.', 'release_date': datetime.date(1941, 4, 30), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 31, 929254, tzinfo=datetime.timezone.utc), 'rating_count': 11, 'rating_avg': Decimal('2.36')}
# {'id': 16, 'title': 'Dancer in the Dark', 'overview': "Selma, a Czech immigrant on the verge of blindness, struggles to make ends meet for herself and her son, who has inherited the same genetic disorder and will suffer the same fate without an expensive operation. When life gets too difficult, Selma learns to cope through her love of musicals, escaping life's troubles - even if just for a moment - by dreaming up little numbers to the rhythmic beats of her surroundings.", 'release_date': datetime.date(2000, 5, 17), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 31, 931053, tzinfo=datetime.timezone.utc), 'rating_count': 88, 'rating_avg': Decimal('4.07')}
# {'id': 3910, 'title': 'Dancer in the Dark', 'overview': "Selma, a Czech immigrant on the verge of blindness, struggles to make ends meet for herself and her son, who has inherited the same genetic disorder and will suffer the same fate without an expensive operation. When life gets too difficult, Selma learns to cope through her love of musicals, escaping life's troubles - even if just for a moment - by dreaming up little numbers to the rhythmic beats of her surroundings.", 'release_date': datetime.date(2000, 5, 17), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 31, 931053, tzinfo=datetime.timezone.utc), 'rating_count': 88, 'rating_avg': Decimal('4.07')}
# {'id': 18, 'title': 'The Fifth Element', 'overview': 'In 2257, a taxi driver is unintentionally given the task of saving a young girl who is part of the key that will ensure the survival of humanity.', 'release_date': datetime.date(1997, 5, 7), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 31, 934639, tzinfo=datetime.timezone.utc), 'rating_count': 26, 'rating_avg': Decimal('3.38')}
# {'id': 1527, 'title': 'The Fifth Element', 'overview': 'In 2257, a taxi driver is unintentionally given the task of saving a young girl who is part of the key that will ensure the survival of humanity.', 'release_date': datetime.date(1997, 5, 7), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 31, 934639, tzinfo=datetime.timezone.utc), 'rating_count': 26, 'rating_avg': Decimal('3.38')}
# {'id': 20, 'title': 'My Life Without Me', 'overview': 'A Pedro Almodovar production in which a fatally ill mother with only two months to live creates a list of things she wants to do before she dies with out telling her family of her illness.', 'release_date': datetime.date(2003, 3, 7), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 31, 938482, tzinfo=datetime.timezone.utc), 'rating_count': 13, 'rating_avg': Decimal('2.69')}
# {'id': 6770, 'title': 'My Life Without Me', 'overview': 'A Pedro Almodovar production in which a fatally ill mother with only two months to live creates a list of things she wants to do before she dies with out telling her family of her illness.', 'release_date': datetime.date(2003, 3, 7), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 31, 938482, tzinfo=datetime.timezone.utc), 'rating_count': 13, 'rating_avg': Decimal('2.69')}
# {'id': 21, 'title': 'The Endless Summer', 'overview': 'The Endless Summer, by Bruce Brown, is one of the first and most influential surf movies of all times. The film documents American surfers Mike Hynson and Robert August as they travel the world during California’s winter (which back in 1965 was off-season for surfing) in search of the perfect wave and an endless summer.', 'release_date': datetime.date(1966, 6, 15), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 31, 940558, tzinfo=datetime.timezone.utc), 'rating_count': 95, 'rating_avg': Decimal('3.61')}
# {'id': 3653, 'title': 'The Endless Summer', 'overview': 'The Endless Summer, by Bruce Brown, is one of the first and most influential surf movies of all times. The film documents American surfers Mike Hynson and Robert August as they travel the world during California’s winter (which back in 1965 was off-season for surfing) in search of the perfect wave and an endless summer.', 'release_date': datetime.date(1966, 6, 15), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 31, 940558, tzinfo=datetime.timezone.utc), 'rating_count': 95, 'rating_avg': Decimal('3.61')}
# {'id': 22, 'title': 'Pirates of the Caribbean: The Curse of the Black Pearl', 'overview': "Jack Sparrow, a freewheeling 17th-century pirate who roams the Caribbean Sea, butts heads with a rival pirate bent on pillaging the village of Port Royal. When the governor's daughter is kidnapped, Sparrow decides to help the girl's love save her. But their seafaring mission is hardly simple.", 'release_date': datetime.date(2003, 7, 9), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 31, 942570, tzinfo=datetime.timezone.utc), 'rating_count': 38, 'rating_avg': Decimal('3.42')}
# {'id': 6539, 'title': 'Pirates of the Caribbean: The Curse of the Black Pearl', 'overview': "Jack Sparrow, a freewheeling 17th-century pirate who roams the Caribbean Sea, butts heads with a rival pirate bent on pillaging the village of Port Royal. When the governor's daughter is kidnapped, Sparrow decides to help the girl's love save her. But their seafaring mission is hardly simple.", 'release_date': datetime.date(2003, 7, 9), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 31, 942570, tzinfo=datetime.timezone.utc), 'rating_count': 38, 'rating_avg': Decimal('3.42')}
# {'id': 24, 'title': 'Kill Bill: Vol. 1', 'overview': "An assassin is shot at the altar by her ruthless employer, Bill and other members of their assassination circle – but 'The Bride' lives to plot her vengeance. Setting out for some payback, she makes a death list and hunts down those who wronged her, saving Bill for last.", 'release_date': datetime.date(2003, 10, 10), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 31, 945068, tzinfo=datetime.timezone.utc), 'rating_count': 34, 'rating_avg': Decimal('3.18')}
# {'id': 6874, 'title': 'Kill Bill: Vol. 1', 'overview': "An assassin is shot at the altar by her ruthless employer, Bill and other members of their assassination circle – but 'The Bride' lives to plot her vengeance. Setting out for some payback, she makes a death list and hunts down those who wronged her, saving Bill for last.", 'release_date': datetime.date(2003, 10, 10), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 31, 945068, tzinfo=datetime.timezone.utc), 'rating_count': 34, 'rating_avg': Decimal('3.18')}
# {'id': 25, 'title': 'Jarhead', 'overview': 'Jarhead is a film about a US Marine Anthony Swofford’s experience in the Gulf War. After putting up with an arduous boot camp, Swafford and his unit are sent to the Persian Gulf where they are earger to fight but are forced to stay back from the action. Meanwhile Swofford gets news of his girlfriend is cheating on him. Desperately he wants to kill someone and finally put his training to use.', 'release_date': datetime.date(2005, 11, 4), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 31, 946898, tzinfo=datetime.timezone.utc), 'rating_count': 101, 'rating_avg': Decimal('3.79')}
# {'id': 40278, 'title': 'Jarhead', 'overview': 'Jarhead is a film about a US Marine Anthony Swofford’s experience in the Gulf War. After putting up with an arduous boot camp, Swafford and his unit are sent to the Persian Gulf where they are earger to fight but are forced to stay back from the action. Meanwhile Swofford gets news of his girlfriend is cheating on him. Desperately he wants to kill someone and finally put his training to use.', 'release_date': datetime.date(2005, 11, 4), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 31, 946898, tzinfo=datetime.timezone.utc), 'rating_count': 101, 'rating_avg': Decimal('3.79')}
# {'id': 26, 'title': 'Walk on Water', 'overview': "Eyal, an Israeli Mossad agent, is given the mission to track down and kill the very old Alfred Himmelman, an ex-Nazi officer, who might still be alive. Pretending to be a tourist guide, he befriends his grandson Axel, in Israel to visit his sister Pia. The two men set out on a tour of the country during which, Axel challenges Eyal's values.", 'release_date': datetime.date(2004, 2, 5), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 31, 948946, tzinfo=datetime.timezone.utc), 'rating_count': 5, 'rating_avg': Decimal('4.20')}
# {'id': 32025, 'title': 'Walk on Water', 'overview': "Eyal, an Israeli Mossad agent, is given the mission to track down and kill the very old Alfred Himmelman, an ex-Nazi officer, who might still be alive. Pretending to be a tourist guide, he befriends his grandson Axel, in Israel to visit his sister Pia. The two men set out on a tour of the country during which, Axel challenges Eyal's values.", 'release_date': datetime.date(2004, 2, 5), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 31, 948946, tzinfo=datetime.timezone.utc), 'rating_count': 5, 'rating_avg': Decimal('4.20')}
# {'id': 28, 'title': 'Apocalypse Now', 'overview': 'At the height of the Vietnam war, Captain Benjamin Willard is sent on a dangerous mission that, officially, "does not exist, nor will it ever exist." His goal is to locate - and eliminate - a mysterious Green Beret Colonel named Walter Kurtz, who has been leading his personal army on illegal guerrilla missions into enemy territory.', 'release_date': datetime.date(1979, 8, 15), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 31, 953185, tzinfo=datetime.timezone.utc), 'rating_count': 18, 'rating_avg': Decimal('4.11')}
# {'id': 1208, 'title': 'Apocalypse Now', 'overview': 'At the height of the Vietnam war, Captain Benjamin Willard is sent on a dangerous mission that, officially, "does not exist, nor will it ever exist." His goal is to locate - and eliminate - a mysterious Green Beret Colonel named Walter Kurtz, who has been leading his personal army on illegal guerrilla missions into enemy territory.', 'release_date': datetime.date(1979, 8, 15), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 31, 953185, tzinfo=datetime.timezone.utc), 'rating_count': 18, 'rating_avg': Decimal('4.11')}
# {'id': 38, 'title': 'Eternal Sunshine of the Spotless Mind', 'overview': 'Joel Barish, heartbroken that his girlfriend underwent a procedure to erase him from her memory, decides to do the same. However, as he watches his memories of her fade away, he realises that he still loves her, and may be too late to correct his mistake.', 'release_date': datetime.date(2004, 3, 19), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 31, 960427, tzinfo=datetime.timezone.utc), 'rating_count': 2, 'rating_avg': Decimal('2.00')}
# {'id': 7361, 'title': 'Eternal Sunshine of the Spotless Mind', 'overview': 'Joel Barish, heartbroken that his girlfriend underwent a procedure to erase him from her memory, decides to do the same. However, as he watches his memories of her fade away, he realises that he still loves her, and may be too late to correct his mistake.', 'release_date': datetime.date(2004, 3, 19), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 31, 960427, tzinfo=datetime.timezone.utc), 'rating_count': 2, 'rating_avg': Decimal('2.00')}
# {'id': 59, 'title': 'A History of Violence', 'overview': 'An average family is thrust into the spotlight after the father commits a seemingly self-defense murder at his diner.', 'release_date': datetime.date(2005, 9, 23), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 31, 968974, tzinfo=datetime.timezone.utc), 'rating_count': 2, 'rating_avg': Decimal('4.00')}
# {'id': 37733, 'title': 'A History of Violence', 'overview': 'An average family is thrust into the spotlight after the father commits a seemingly self-defense murder at his diner.', 'release_date': datetime.date(2005, 9, 23), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 31, 968974, tzinfo=datetime.timezone.utc), 'rating_count': 2, 'rating_avg': Decimal('4.00')}
# {'id': 63, 'title': 'Twelve Monkeys', 'overview': "In the year 2035, convict James Cole reluctantly volunteers to be sent back in time to discover the origin of a deadly virus that wiped out nearly all of the earth's population and forced the survivors into underground communities. But when Cole is mistakenly sent to 1990 instead of 1996, he's arrested and locked up in a mental hospital. There he meets psychiatrist Dr. Kathryn Railly, and patient Jeffrey Goines, the son of a famous virus expert, who may hold the key to the mysterious rogue group, the Army of the 12 Monkeys, thought to be responsible for unleashing the killer disease.", 'release_date': datetime.date(1995, 12, 29), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 31, 974528, tzinfo=datetime.timezone.utc), 'rating_count': 6, 'rating_avg': Decimal('3.00')}
# {'id': 32, 'title': 'Twelve Monkeys', 'overview': "In the year 2035, convict James Cole reluctantly volunteers to be sent back in time to discover the origin of a deadly virus that wiped out nearly all of the earth's population and forced the survivors into underground communities. But when Cole is mistakenly sent to 1990 instead of 1996, he's arrested and locked up in a mental hospital. There he meets psychiatrist Dr. Kathryn Railly, and patient Jeffrey Goines, the son of a famous virus expert, who may hold the key to the mysterious rogue group, the Army of the 12 Monkeys, thought to be responsible for unleashing the killer disease.", 'release_date': datetime.date(1995, 12, 29), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 31, 974528, tzinfo=datetime.timezone.utc), 'rating_count': 6, 'rating_avg': Decimal('3.00')}
# {'id': 64, 'title': 'Talk to Her', 'overview': 'Two men share an odd friendship while they care for two women who are both in deep comas.', 'release_date': datetime.date(2002, 3, 14), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 31, 977057, tzinfo=datetime.timezone.utc), 'rating_count': 10, 'rating_avg': Decimal('2.40')}
# {'id': 5878, 'title': 'Talk to Her', 'overview': 'Two men share an odd friendship while they care for two women who are both in deep comas.', 'release_date': datetime.date(2002, 3, 14), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 31, 977057, tzinfo=datetime.timezone.utc), 'rating_count': 10, 'rating_avg': Decimal('2.40')}
# {'id': 65, 'title': '8 Mile', 'overview': 'The setting is Detroit in 1995. The city is divided by 8 Mile, a road that splits the town in half along racial lines. A young white rapper, Jimmy "B-Rabbit" Smith Jr. summons strength within himself to cross over these arbitrary boundaries to fulfill his dream of success in hip hop. With his pal Future and the three one third in place, all he has to do is not choke.', 'release_date': datetime.date(2002, 11, 8), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 31, 979453, tzinfo=datetime.timezone.utc), 'rating_count': 20, 'rating_avg': Decimal('2.10')}
# {'id': 5810, 'title': '8 Mile', 'overview': 'The setting is Detroit in 1995. The city is divided by 8 Mile, a road that splits the town in half along racial lines. A young white rapper, Jimmy "B-Rabbit" Smith Jr. summons strength within himself to cross over these arbitrary boundaries to fulfill his dream of success in hip hop. With his pal Future and the three one third in place, all he has to do is not choke.', 'release_date': datetime.date(2002, 11, 8), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 31, 979453, tzinfo=datetime.timezone.utc), 'rating_count': 20, 'rating_avg': Decimal('2.10')}
# {'id': 66, 'title': 'Absolute Power', 'overview': 'A master thief coincidentally is robbing a house where a murder in which the President of The United States is involved occurs in front of his eyes. He is forced to run yet may hold evidence that could convict the President. A political thriller from and starring Clint Eastwood and based on a novel by David Baldacci.', 'release_date': datetime.date(1997, 2, 14), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 31, 983222, tzinfo=datetime.timezone.utc), 'rating_count': 5, 'rating_avg': Decimal('2.00')}
# {'id': 1459, 'title': 'Absolute Power', 'overview': 'A master thief coincidentally is robbing a house where a murder in which the President of The United States is involved occurs in front of his eyes. He is forced to run yet may hold evidence that could convict the President. A political thriller from and starring Clint Eastwood and based on a novel by David Baldacci.', 'release_date': datetime.date(1997, 2, 14), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 31, 983222, tzinfo=datetime.timezone.utc), 'rating_count': 5, 'rating_avg': Decimal('2.00')}
# {'id': 67, 'title': 'Paradise Now', 'overview': 'Paradise Now is filmed from the perspective of two Palestinian men who are preparing to perform a suicide attack in Israel. This is the first film to deal with the subject of suicide bombers.', 'release_date': datetime.date(2005, 2, 14), 'rating_last_updated': datetime.datetime(2024, 1, 18, 23, 48, 35, 245786, tzinfo=datetime.timezone.utc), 'rating_count': 4, 'rating_avg': Decimal('2.50')}
# {'id': 41527, 'title': 'Paradise Now', 'overview': 'Paradise Now is filmed from the perspective of two Palestinian men who are preparing to perform a suicide attack in Israel. This is the first film to deal with the subject of suicide bombers.', 'release_date': datetime.date(2005, 2, 14), 'rating_last_updated': datetime.datetime(2024, 1, 18, 23, 48, 35, 245786, tzinfo=datetime.timezone.utc), 'rating_count': 4, 'rating_avg': Decimal('2.50')}
# {'id': 68, 'title': 'Brazil', 'overview': 'Low-level bureaucrat Sam Lowry escapes the monotony of his day-to-day life through a recurring daydream of himself as a virtuous hero saving a beautiful damsel. Investigating a case that led to the wrongful arrest and eventual death of an innocent man instead of wanted terrorist Harry Tuttle, he meets the woman from his daydream, and in trying to help her gets caught in a web of mistaken identities, mindless bureaucracy and lies.', 'release_date': datetime.date(1985, 2, 20), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 31, 985716, tzinfo=datetime.timezone.utc), 'rating_count': 8, 'rating_avg': Decimal('3.50')}
# {'id': 1199, 'title': 'Brazil', 'overview': 'Low-level bureaucrat Sam Lowry escapes the monotony of his day-to-day life through a recurring daydream of himself as a virtuous hero saving a beautiful damsel. Investigating a case that led to the wrongful arrest and eventual death of an innocent man instead of wanted terrorist Harry Tuttle, he meets the woman from his daydream, and in trying to help her gets caught in a web of mistaken identities, mindless bureaucracy and lies.', 'release_date': datetime.date(1985, 2, 20), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 31, 985716, tzinfo=datetime.timezone.utc), 'rating_count': 8, 'rating_avg': Decimal('3.50')}
# {'id': 71, 'title': 'Billy Elliot', 'overview': "Set against the background of the 1984 Miner's Strike, Billy Elliot is an 11 year old boy who stumbles out of the boxing ring and onto the ballet floor. He faces many trials and triumphs as he strives to conquer his family's set ways, inner conflict, and standing on his toes!", 'release_date': datetime.date(2000, 5, 18), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 31, 995420, tzinfo=datetime.timezone.utc), 'rating_count': 7, 'rating_avg': Decimal('2.57')}
# {'id': 3967, 'title': 'Billy Elliot', 'overview': "Set against the background of the 1984 Miner's Strike, Billy Elliot is an 11 year old boy who stumbles out of the boxing ring and onto the ballet floor. He faces many trials and triumphs as he strives to conquer his family's set ways, inner conflict, and standing on his toes!", 'release_date': datetime.date(2000, 5, 18), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 31, 995420, tzinfo=datetime.timezone.utc), 'rating_count': 7, 'rating_avg': Decimal('2.57')}
# {'id': 73, 'title': 'American History X', 'overview': "Derek Vineyard is paroled after serving 3 years in prison for killing two thugs who tried to break into/steal his truck. Through his brother, Danny Vineyard's narration, we learn that before going to prison, Derek was a skinhead and the leader of a violent white supremacist gang that committed acts of racial crime throughout L.A. and his actions greatly influenced Danny. Reformed and fresh out of prison, Derek severs contact with the gang and becomes determined to keep Danny from going down the same violent path as he did.", 'release_date': datetime.date(1998, 10, 30), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 31, 999790, tzinfo=datetime.timezone.utc), 'rating_count': 13, 'rating_avg': Decimal('4.15')}
# {'id': 2329, 'title': 'American History X', 'overview': "Derek Vineyard is paroled after serving 3 years in prison for killing two thugs who tried to break into/steal his truck. Through his brother, Danny Vineyard's narration, we learn that before going to prison, Derek was a skinhead and the leader of a violent white supremacist gang that committed acts of racial crime throughout L.A. and his actions greatly influenced Danny. Reformed and fresh out of prison, Derek severs contact with the gang and becomes determined to keep Danny from going down the same violent path as he did.", 'release_date': datetime.date(1998, 10, 30), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 31, 999790, tzinfo=datetime.timezone.utc), 'rating_count': 13, 'rating_avg': Decimal('4.15')}
# {'id': 74, 'title': 'War of the Worlds', 'overview': 'Ray Ferrier is a divorced dockworker and less-than-perfect father. Soon after his ex-wife and her new husband drop of his teenage son and young daughter for a rare weekend visit, a strange and powerful lightning storm touches down.', 'release_date': datetime.date(2005, 6, 28), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 32, 3689, tzinfo=datetime.timezone.utc), 'rating_count': 19, 'rating_avg': Decimal('3.05')}
# {'id': 34048, 'title': 'War of the Worlds', 'overview': 'Ray Ferrier is a divorced dockworker and less-than-perfect father. Soon after his ex-wife and her new husband drop of his teenage son and young daughter for a rare weekend visit, a strange and powerful lightning storm touches down.', 'release_date': datetime.date(2005, 6, 28), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 32, 3689, tzinfo=datetime.timezone.utc), 'rating_count': 19, 'rating_avg': Decimal('3.05')}
# {'id': 80, 'title': 'Before Sunset', 'overview': 'Nine years ago two strangers met by chance and spent a night in Vienna that ended before sunrise. They are about to meet for the first time since. Now they have one afternoon to find out if they belong together.', 'release_date': datetime.date(2004, 2, 10), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 32, 20694, tzinfo=datetime.timezone.utc), 'rating_count': 4, 'rating_avg': Decimal('4.75')}
# {'id': 8638, 'title': 'Before Sunset', 'overview': 'Nine years ago two strangers met by chance and spent a night in Vienna that ended before sunrise. They are about to meet for the first time since. Now they have one afternoon to find out if they belong together.', 'release_date': datetime.date(2004, 2, 10), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 32, 20694, tzinfo=datetime.timezone.utc), 'rating_count': 4, 'rating_avg': Decimal('4.75')}
# {'id': 81, 'title': 'Nausicaä of the Valley of the Wind', 'overview': 'After a global war, the seaside kingdom known as the Valley Of The Wind remains one of the last strongholds on Earth untouched by a poisonous jungle and the powerful insects that guard it. Led by the courageous Princess Nausicaa, the people of the Valley engage in an epic struggle to restore the bond between humanity and Earth.', 'release_date': datetime.date(1984, 3, 11), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 32, 23048, tzinfo=datetime.timezone.utc), 'rating_count': 18, 'rating_avg': Decimal('3.28')}
# {'id': 7099, 'title': 'Nausicaä of the Valley of the Wind', 'overview': 'After a global war, the seaside kingdom known as the Valley Of The Wind remains one of the last strongholds on Earth untouched by a poisonous jungle and the powerful insects that guard it. Led by the courageous Princess Nausicaa, the people of the Valley engage in an epic struggle to restore the bond between humanity and Earth.', 'release_date': datetime.date(1984, 3, 11), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 32, 23048, tzinfo=datetime.timezone.utc), 'rating_count': 18, 'rating_avg': Decimal('3.28')}
# {'id': 82, 'title': 'Miami Vice', 'overview': 'Miami Vice is a feature film based on the 1980s action drama TV series. The film tells the story of vice detectives Crockett and Tubbs and how their personal and professional lives are dangerously getting mixed.', 'release_date': datetime.date(2006, 7, 27), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 32, 24995, tzinfo=datetime.timezone.utc), 'rating_count': 10, 'rating_avg': Decimal('3.80')}
# {'id': 47044, 'title': 'Miami Vice', 'overview': 'Miami Vice is a feature film based on the 1980s action drama TV series. The film tells the story of vice detectives Crockett and Tubbs and how their personal and professional lives are dangerously getting mixed.', 'release_date': datetime.date(2006, 7, 27), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 32, 24995, tzinfo=datetime.timezone.utc), 'rating_count': 10, 'rating_avg': Decimal('3.80')}
# {'id': 83, 'title': 'Open Water', 'overview': 'Two divers are left out at sea without a boat. There’s nothing but water for miles, unless they look at what’s underneath them...', 'release_date': datetime.date(2004, 8, 6), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 32, 27068, tzinfo=datetime.timezone.utc), 'rating_count': 3, 'rating_avg': Decimal('3.00')}
# {'id': 27822, 'title': 'Open Water', 'overview': 'Two divers are left out at sea without a boat. There’s nothing but water for miles, unless they look at what’s underneath them...', 'release_date': datetime.date(2004, 8, 6), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 32, 27068, tzinfo=datetime.timezone.utc), 'rating_count': 3, 'rating_avg': Decimal('3.00')}
# {'id': 85, 'title': 'Raiders of the Lost Ark', 'overview': 'When Dr. Indiana Jones – the tweed-suited professor who just happens to be a celebrated archaeologist – is hired by the government to locate the legendary Ark of the Covenant, he finds himself up against the entire Nazi regime.', 'release_date': datetime.date(1981, 6, 12), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 32, 30091, tzinfo=datetime.timezone.utc), 'rating_count': 16, 'rating_avg': Decimal('4.06')}
# {'id': 1198, 'title': 'Raiders of the Lost Ark', 'overview': 'When Dr. Indiana Jones – the tweed-suited professor who just happens to be a celebrated archaeologist – is hired by the government to locate the legendary Ark of the Covenant, he finds himself up against the entire Nazi regime.', 'release_date': datetime.date(1981, 6, 12), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 32, 30091, tzinfo=datetime.timezone.utc), 'rating_count': 16, 'rating_avg': Decimal('4.06')}
# {'id': 89, 'title': 'Indiana Jones and the Last Crusade', 'overview': "When Dr. Henry Jones Sr. suddenly goes missing while pursuing the Holy Grail, eminent archaeologist Indiana must team up with Marcus Brody, Sallah and Elsa Schneider to follow in his father's footsteps and stop the Nazis from recovering the power of eternal life.", 'release_date': datetime.date(1989, 5, 24), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 32, 39841, tzinfo=datetime.timezone.utc), 'rating_count': 17, 'rating_avg': Decimal('3.47')}
# {'id': 1291, 'title': 'Indiana Jones and the Last Crusade', 'overview': "When Dr. Henry Jones Sr. suddenly goes missing while pursuing the Holy Grail, eminent archaeologist Indiana must team up with Marcus Brody, Sallah and Elsa Schneider to follow in his father's footsteps and stop the Nazis from recovering the power of eternal life.", 'release_date': datetime.date(1989, 5, 24), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 32, 39841, tzinfo=datetime.timezone.utc), 'rating_count': 17, 'rating_avg': Decimal('3.47')}
# {'id': 90, 'title': 'Beverly Hills Cop', 'overview': "Tough-talking Detroit cop Axel Foley heads to the rarified world of Beverly Hills in his beat-up Chevy Nova to investigate a friend's murder. But soon, he realizes he's stumbled onto something much more complicated. Bungling rookie detective Billy Rosewood joins the fish-out-of-water Axel and shows him the West Los Angeles ropes.", 'release_date': datetime.date(1984, 11, 29), 'rating_last_updated': datetime.datetime(2024, 1, 18, 23, 48, 35, 327482, tzinfo=datetime.timezone.utc), 'rating_count': 12, 'rating_avg': Decimal('3.17')}
# {'id': 4085, 'title': 'Beverly Hills Cop', 'overview': "Tough-talking Detroit cop Axel Foley heads to the rarified world of Beverly Hills in his beat-up Chevy Nova to investigate a friend's murder. But soon, he realizes he's stumbled onto something much more complicated. Bungling rookie detective Billy Rosewood joins the fish-out-of-water Axel and shows him the West Los Angeles ropes.", 'release_date': datetime.date(1984, 11, 29), 'rating_last_updated': datetime.datetime(2024, 1, 18, 23, 48, 35, 327482, tzinfo=datetime.timezone.utc), 'rating_count': 12, 'rating_avg': Decimal('3.17')}
# {'id': 93, 'title': 'Anatomy of a Murder', 'overview': 'The film pits a humble small-town lawyer against a hard-headed big city prosecutor. Emotions flare as a jealous army lieutenant pleads innocent to murdering the rapist of his seductive, beautiful wife.', 'release_date': datetime.date(1959, 7, 1), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 32, 44839, tzinfo=datetime.timezone.utc), 'rating_count': 11, 'rating_avg': Decimal('2.27')}
# {'id': 3801, 'title': 'Anatomy of a Murder', 'overview': 'The film pits a humble small-town lawyer against a hard-headed big city prosecutor. Emotions flare as a jealous army lieutenant pleads innocent to murdering the rapist of his seductive, beautiful wife.', 'release_date': datetime.date(1959, 7, 1), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 32, 44839, tzinfo=datetime.timezone.utc), 'rating_count': 11, 'rating_avg': Decimal('2.27')}
# {'id': 96, 'title': 'Beverly Hills Cop II', 'overview': "Detroit cop, Axel Foley heads for the land of sunshine and palm trees to find out who shot police Captain Andrew Bogomil. Thanks to a couple of old friends, Axel's investigation uncovers a series of robberies masterminded by a heartless weapons kingpin – and the chase is on.", 'release_date': datetime.date(1987, 5, 18), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 32, 50385, tzinfo=datetime.timezone.utc), 'rating_count': 1, 'rating_avg': Decimal('1.00')}
# {'id': 4084, 'title': 'Beverly Hills Cop II', 'overview': "Detroit cop, Axel Foley heads for the land of sunshine and palm trees to find out who shot police Captain Andrew Bogomil. Thanks to a couple of old friends, Axel's investigation uncovers a series of robberies masterminded by a heartless weapons kingpin – and the chase is on.", 'release_date': datetime.date(1987, 5, 18), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 32, 50385, tzinfo=datetime.timezone.utc), 'rating_count': 1, 'rating_avg': Decimal('1.00')}
# {'id': 98, 'title': 'Gladiator', 'overview': "In the year 180, the death of emperor Marcus Aurelius throws the Roman Empire into chaos. Maximus is one of the Roman army's most capable and trusted generals and a key advisor to the emperor. As Marcus' devious son Commodus ascends to the throne, Maximus is set to be executed. He escapes, but is captured by slave traders. Renamed Spaniard and forced to become a gladiator, Maximus must battle to the death with other men for the amusement of paying audiences. His battle skills serve him well, and he becomes one of the most famous and admired men to fight in the Colosseum. Determined to avenge himself against the man who took away his freedom and laid waste to his family, Maximus believes that he can use his fame and skill in the ring to avenge the loss of his family and former glory. As the gladiator begins to challenge his rule, Commodus decides to put his own fighting mettle to the test by squaring off with Maximus in a battle to the death.", 'release_date': datetime.date(2000, 5, 1), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 32, 56019, tzinfo=datetime.timezone.utc), 'rating_count': 1, 'rating_avg': Decimal('3.00')}
# {'id': 3578, 'title': 'Gladiator', 'overview': "In the year 180, the death of emperor Marcus Aurelius throws the Roman Empire into chaos. Maximus is one of the Roman army's most capable and trusted generals and a key advisor to the emperor. As Marcus' devious son Commodus ascends to the throne, Maximus is set to be executed. He escapes, but is captured by slave traders. Renamed Spaniard and forced to become a gladiator, Maximus must battle to the death with other men for the amusement of paying audiences. His battle skills serve him well, and he becomes one of the most famous and admired men to fight in the Colosseum. Determined to avenge himself against the man who took away his freedom and laid waste to his family, Maximus believes that he can use his fame and skill in the ring to avenge the loss of his family and former glory. As the gladiator begins to challenge his rule, Commodus decides to put his own fighting mettle to the test by squaring off with Maximus in a battle to the death.", 'release_date': datetime.date(2000, 5, 1), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 32, 56019, tzinfo=datetime.timezone.utc), 'rating_count': 1, 'rating_avg': Decimal('3.00')}
# {'id': 100, 'title': 'Lock, Stock and Two Smoking Barrels', 'overview': 'A card sharp and his unwillingly-enlisted friends need to make a lot of cash quick after losing a sketchy poker match. To do this they decide to pull a heist on a small-time gang who happen to be operating out of the flat next door.', 'release_date': datetime.date(1998, 3, 5), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 32, 61903, tzinfo=datetime.timezone.utc), 'rating_count': 21, 'rating_avg': Decimal('3.43')}
# {'id': 2542, 'title': 'Lock, Stock and Two Smoking Barrels', 'overview': 'A card sharp and his unwillingly-enlisted friends need to make a lot of cash quick after losing a sketchy poker match. To do this they decide to pull a heist on a small-time gang who happen to be operating out of the flat next door.', 'release_date': datetime.date(1998, 3, 5), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 32, 61903, tzinfo=datetime.timezone.utc), 'rating_count': 21, 'rating_avg': Decimal('3.43')}
# {'id': 105, 'title': 'Back to the Future', 'overview': "Eighties teenager Marty McFly is accidentally sent back in time to 1955, inadvertently disrupting his parents' first meeting and attracting his mother's romantic interest. Marty must repair the damage to history by rekindling his parents' romance and - with the help of his eccentric inventor friend Doc Brown - return to 1985.", 'release_date': datetime.date(1985, 7, 3), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 32, 79497, tzinfo=datetime.timezone.utc), 'rating_count': 48, 'rating_avg': Decimal('3.19')}
# {'id': 1270, 'title': 'Back to the Future', 'overview': "Eighties teenager Marty McFly is accidentally sent back in time to 1955, inadvertently disrupting his parents' first meeting and attracting his mother's romantic interest. Marty must repair the damage to history by rekindling his parents' romance and - with the help of his eccentric inventor friend Doc Brown - return to 1985.", 'release_date': datetime.date(1985, 7, 3), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 32, 79497, tzinfo=datetime.timezone.utc), 'rating_count': 48, 'rating_avg': Decimal('3.19')}
# {'id': 111, 'title': 'Scarface', 'overview': 'After getting a green card in exchange for assassinating a Cuban government official, Tony Montana stakes a claim on the drug trade in Miami. Viciously murdering anyone who stands in his way, Tony eventually becomes the biggest drug lord in the state, controlling nearly all the cocaine that comes through Miami. But increased pressure from the police, wars with Colombian drug cartels and his own drug-fueled paranoia serve to fuel the flames of his eventual downfall.', 'release_date': datetime.date(1983, 12, 8), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 32, 101265, tzinfo=datetime.timezone.utc), 'rating_count': 118, 'rating_avg': Decimal('4.32')}
# {'id': 4262, 'title': 'Scarface', 'overview': 'After getting a green card in exchange for assassinating a Cuban government official, Tony Montana stakes a claim on the drug trade in Miami. Viciously murdering anyone who stands in his way, Tony eventually becomes the biggest drug lord in the state, controlling nearly all the cocaine that comes through Miami. But increased pressure from the police, wars with Colombian drug cartels and his own drug-fueled paranoia serve to fuel the flames of his eventual downfall.', 'release_date': datetime.date(1983, 12, 8), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 32, 101265, tzinfo=datetime.timezone.utc), 'rating_count': 118, 'rating_avg': Decimal('4.32')}
# {'id': 115, 'title': 'The Big Lebowski', 'overview': 'Jeffrey "The Dude" Lebowski, a Los Angeles slacker who only wants to bowl and drink white Russians, is mistaken for another Jeffrey Lebowski, a wheelchair-bound millionaire, and finds himself dragged into a strange series of events involving nihilists, adult film producers, ferrets, errant toes, and large sums of money.', 'release_date': datetime.date(1998, 3, 6), 'rating_last_updated': datetime.datetime(2024, 1, 18, 23, 48, 35, 425625, tzinfo=datetime.timezone.utc), 'rating_count': 6, 'rating_avg': Decimal('2.50')}
# {'id': 1732, 'title': 'The Big Lebowski', 'overview': 'Jeffrey "The Dude" Lebowski, a Los Angeles slacker who only wants to bowl and drink white Russians, is mistaken for another Jeffrey Lebowski, a wheelchair-bound millionaire, and finds himself dragged into a strange series of events involving nihilists, adult film producers, ferrets, errant toes, and large sums of money.', 'release_date': datetime.date(1998, 3, 6), 'rating_last_updated': datetime.datetime(2024, 1, 18, 23, 48, 35, 425625, tzinfo=datetime.timezone.utc), 'rating_count': 6, 'rating_avg': Decimal('2.50')}
# {'id': 116, 'title': 'Match Point', 'overview': 'Match Point is Woody Allen’s satire of the British High Society and the ambition of a young tennis instructor to enter into it. Yet when he must decide between two women - one assuring him his place in high society, and the other that would bring him far from it - palms start to sweat and a dark psychological match in his head begins.', 'release_date': datetime.date(2005, 10, 26), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 32, 110873, tzinfo=datetime.timezone.utc), 'rating_count': 6, 'rating_avg': Decimal('4.83')}
# {'id': 41285, 'title': 'Match Point', 'overview': 'Match Point is Woody Allen’s satire of the British High Society and the ambition of a young tennis instructor to enter into it. Yet when he must decide between two women - one assuring him his place in high society, and the other that would bring him far from it - palms start to sweat and a dark psychological match in his head begins.', 'release_date': datetime.date(2005, 10, 26), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 32, 110873, tzinfo=datetime.timezone.utc), 'rating_count': 6, 'rating_avg': Decimal('4.83')}
# {'id': 117, 'title': 'The Untouchables', 'overview': "Young Treasury Agent Elliot Ness arrives in Chicago and is determined to take down Al Capone, but it's not going to be easy because Capone has the police in his pocket. Ness meets Jimmy Malone, a veteran patrolman and probably the most honorable one on the force. He asks Malone to help him get Capone, but Malone warns him that if he goes after Capone, he is going to war.", 'release_date': datetime.date(1987, 6, 2), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 32, 113078, tzinfo=datetime.timezone.utc), 'rating_count': 6, 'rating_avg': Decimal('3.00')}
# {'id': 2194, 'title': 'The Untouchables', 'overview': "Young Treasury Agent Elliot Ness arrives in Chicago and is determined to take down Al Capone, but it's not going to be easy because Capone has the police in his pocket. Ness meets Jimmy Malone, a veteran patrolman and probably the most honorable one on the force. He asks Malone to help him get Capone, but Malone warns him that if he goes after Capone, he is going to war.", 'release_date': datetime.date(1987, 6, 2), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 32, 113078, tzinfo=datetime.timezone.utc), 'rating_count': 6, 'rating_avg': Decimal('3.00')}
# {'id': 121, 'title': 'The Lord of the Rings: The Two Towers', 'overview': 'Frodo and Sam are trekking to Mordor to destroy the One Ring of Power while Gimli, Legolas and Aragorn search for the orc-captured Merry and Pippin. All along, nefarious wizard Saruman awaits the Fellowship members at the Orthanc Tower in Isengard.', 'release_date': datetime.date(2002, 12, 18), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 32, 118144, tzinfo=datetime.timezone.utc), 'rating_count': 5, 'rating_avg': Decimal('3.80')}
# {'id': 5952, 'title': 'The Lord of the Rings: The Two Towers', 'overview': 'Frodo and Sam are trekking to Mordor to destroy the One Ring of Power while Gimli, Legolas and Aragorn search for the orc-captured Merry and Pippin. All along, nefarious wizard Saruman awaits the Fellowship members at the Orthanc Tower in Isengard.', 'release_date': datetime.date(2002, 12, 18), 'rating_last_updated': datetime.datetime(2024, 1, 19, 20, 10, 32, 118144, tzinfo=datetime.timezone.utc), 'rating_count': 5, 'rating_avg': Decimal('3.80')}
# ...
# {'id': 22230, 'title': 'Happy Accidents', 'overview': 'A comedy that pays tribute to the science fiction genre -- specifically, the sub-genre of time travel. But here the alternate reality is contemporary New York City where past and future experiences of trust, commitment and denial are cleverly put to the test. Just as Ruby is beginning to relish her first-ever healthy relationship, Sam begins muttering about being a time traveler from the year 2470.', 'release_date': datetime.date(2000, 1, 25), 'rating_last_updated': datetime.datetime(2024, 1, 18, 23, 49, 8, 858300, tzinfo=datetime.timezone.utc), 'rating_count': 8, 'rating_avg': Decimal('3.50')}
# {'id': 4738, 'title': 'Happy Accidents', 'overview': 'A comedy that pays tribute to the science fiction genre -- specifically, the sub-genre of time travel. But here the alternate reality is contemporary New York City where past and future experiences of trust, commitment and denial are cleverly put to the test. Just as Ruby is beginning to relish her first-ever healthy relationship, Sam begins muttering about being a time traveler from the year 2470.', 'release_date': datetime.date(2000, 1, 25), 'rating_last_updated': datetime.datetime(2024, 1, 18, 23, 49, 8, 858300, tzinfo=datetime.timezone.utc), 'rating_count': 8, 'rating_avg': Decimal('3.50')}
# {'id': 22256, 'title': 'Without Limits', 'overview': 'The film follows the life of famous 1970s runner Steve Prefontaine from his youth days in Oregon to the University of Oregon where he worked with the legendary coach Bill Bowerman, later to Olympics in Munich and his early death at 24 in a car crash.', 'release_date': datetime.date(1998, 9, 11), 'rating_last_updated': datetime.datetime(2024, 1, 18, 23, 49, 8, 872993, tzinfo=datetime.timezone.utc), 'rating_count': 8, 'rating_avg': Decimal('3.12')}
# {'id': 2237, 'title': 'Without Limits', 'overview': 'The film follows the life of famous 1970s runner Steve Prefontaine from his youth days in Oregon to the University of Oregon where he worked with the legendary coach Bill Bowerman, later to Olympics in Munich and his early death at 24 in a car crash.', 'release_date': datetime.date(1998, 9, 11), 'rating_last_updated': datetime.datetime(2024, 1, 18, 23, 49, 8, 872993, tzinfo=datetime.timezone.utc), 'rating_count': 8, 'rating_avg': Decimal('3.12')}
# {'id': 22288, 'title': 'Honeysuckle Rose', 'overview': 'Buck Bonham (Willie Nelson) is a country singer, with a good family, struggling to find national fame. He juggles his music career with his responsibilities to his wife and son. He has everything going his way until the daughter of his former guitarist joins his tour. The road leads to temptation, which leads to his downfall. The only question is will his family and friends stand by him?', 'release_date': datetime.date(1980, 7, 18), 'rating_last_updated': datetime.datetime(2024, 1, 18, 23, 49, 8, 889160, tzinfo=datetime.timezone.utc), 'rating_count': 7, 'rating_avg': Decimal('3.43')}
# {'id': 5186, 'title': 'Honeysuckle Rose', 'overview': 'Buck Bonham (Willie Nelson) is a country singer, with a good family, struggling to find national fame. He juggles his music career with his responsibilities to his wife and son. He has everything going his way until the daughter of his former guitarist joins his tour. The road leads to temptation, which leads to his downfall. The only question is will his family and friends stand by him?', 'release_date': datetime.date(1980, 7, 18), 'rating_last_updated': datetime.datetime(2024, 1, 18, 23, 49, 8, 889160, tzinfo=datetime.timezone.utc), 'rating_count': 7, 'rating_avg': Decimal('3.43')}
# {'id': 22293, 'title': 'Manos: The Hands of Fate', 'overview': 'A family gets lost on the road and stumbles upon a hidden, underground, devil-worshiping cult led by the fearsome Master and his servant Torgo.', 'release_date': datetime.date(1966, 11, 15), 'rating_last_updated': datetime.datetime(2024, 1, 18, 23, 49, 8, 896012, tzinfo=datetime.timezone.utc), 'rating_count': 8, 'rating_avg': Decimal('2.25')}
# {'id': 26157, 'title': 'Manos: The Hands of Fate', 'overview': 'A family gets lost on the road and stumbles upon a hidden, underground, devil-worshiping cult led by the fearsome Master and his servant Torgo.', 'release_date': datetime.date(1966, 11, 15), 'rating_last_updated': datetime.datetime(2024, 1, 18, 23, 49, 8, 896012, tzinfo=datetime.timezone.utc), 'rating_count': 8, 'rating_avg': Decimal('2.25')}
# {'id': 22307, 'title': 'Sisters', 'overview': 'A journalist witnesses a brutal murder in a neighboring apartment, but the police do not believe that the crime took place. With the help of a private detective, she seeks out the truth.', 'release_date': datetime.date(1973, 3, 27), 'rating_last_updated': datetime.datetime(2024, 1, 18, 23, 49, 8, 905235, tzinfo=datetime.timezone.utc), 'rating_count': 11, 'rating_avg': Decimal('3.09')}
# {'id': 26303, 'title': 'Sisters', 'overview': 'A journalist witnesses a brutal murder in a neighboring apartment, but the police do not believe that the crime took place. With the help of a private detective, she seeks out the truth.', 'release_date': datetime.date(1973, 3, 27), 'rating_last_updated': datetime.datetime(2024, 1, 18, 23, 49, 8, 905235, tzinfo=datetime.timezone.utc), 'rating_count': 11, 'rating_avg': Decimal('3.09')}
# {'id': 22311, 'title': 'The Inglorious Bastards', 'overview': 'Set in Europe during WWII, a group of American soldiers on their way to military prison are beset upon by a German artillery attack, escaping with Switzerland in their sights. Before making it any farther, they volunteer to steal a V2 warhead for the French Underground - taking them deep into the heart of German territory.', 'release_date': datetime.date(1978, 2, 8), 'rating_last_updated': datetime.datetime(2024, 1, 18, 23, 49, 8, 909547, tzinfo=datetime.timezone.utc), 'rating_count': 5, 'rating_avg': Decimal('4.20')}
# {'id': 52319, 'title': 'The Inglorious Bastards', 'overview': 'Set in Europe during WWII, a group of American soldiers on their way to military prison are beset upon by a German artillery attack, escaping with Switzerland in their sights. Before making it any farther, they volunteer to steal a V2 warhead for the French Underground - taking them deep into the heart of German territory.', 'release_date': datetime.date(1978, 2, 8), 'rating_last_updated': datetime.datetime(2024, 1, 18, 23, 49, 8, 909547, tzinfo=datetime.timezone.utc), 'rating_count': 5, 'rating_avg': Decimal('4.20')}
# {'id': 22314, 'title': 'In Too Deep', 'overview': "A fearless cop is taking on a ruthless crimelord. He knew the risks. He just didn't know how far he would have to go.", 'release_date': datetime.date(1999, 8, 25), 'rating_last_updated': datetime.datetime(2024, 1, 18, 23, 49, 8, 911844, tzinfo=datetime.timezone.utc), 'rating_count': 2, 'rating_avg': Decimal('3.50')}
# {'id': 2812, 'title': 'In Too Deep', 'overview': "A fearless cop is taking on a ruthless crimelord. He knew the risks. He just didn't know how far he would have to go.", 'release_date': datetime.date(1999, 8, 25), 'rating_last_updated': datetime.datetime(2024, 1, 18, 23, 49, 8, 911844, tzinfo=datetime.timezone.utc), 'rating_count': 2, 'rating_avg': Decimal('3.50')}
# {'id': 22317, 'title': 'Lightning Jack', 'overview': "Lightning Jack Kane is an Australian outlaw in the wild west. During a bungled bank robbery he picks up mute Ben Doyle as a hostage. The two become good friends, with Jack teaching Ben how to rob banks, while they plan Jack's last heist.", 'release_date': datetime.date(1994, 3, 11), 'rating_last_updated': datetime.datetime(2024, 1, 18, 23, 49, 8, 920224, tzinfo=datetime.timezone.utc), 'rating_count': 14, 'rating_avg': Decimal('3.21')}
# {'id': 487, 'title': 'Lightning Jack', 'overview': "Lightning Jack Kane is an Australian outlaw in the wild west. During a bungled bank robbery he picks up mute Ben Doyle as a hostage. The two become good friends, with Jack teaching Ben how to rob banks, while they plan Jack's last heist.", 'release_date': datetime.date(1994, 3, 11), 'rating_last_updated': datetime.datetime(2024, 1, 18, 23, 49, 8, 920224, tzinfo=datetime.timezone.utc), 'rating_count': 14, 'rating_avg': Decimal('3.21')}
# {'id': 22318, 'title': 'Permanent Midnight', 'overview': "Ben Stiller plays comedy writer Jerry Stahl, whose $6000-a-week heroin habit had him taking his infant daughter along on his drug runs and doing smack during TV script conferences. Departing detox, Stahl explores memories with survivor Kitty, who listens patiently to Stahl's flashback. Other women in Stahl's life are his British wife Sandra and his agent Vola.", 'release_date': datetime.date(1998, 9, 12), 'rating_last_updated': datetime.datetime(2024, 1, 18, 23, 49, 8, 922470, tzinfo=datetime.timezone.utc), 'rating_count': 7, 'rating_avg': Decimal('2.71')}
# {'id': 2271, 'title': 'Permanent Midnight', 'overview': "Ben Stiller plays comedy writer Jerry Stahl, whose $6000-a-week heroin habit had him taking his infant daughter along on his drug runs and doing smack during TV script conferences. Departing detox, Stahl explores memories with survivor Kitty, who listens patiently to Stahl's flashback. Other women in Stahl's life are his British wife Sandra and his agent Vola.", 'release_date': datetime.date(1998, 9, 12), 'rating_last_updated': datetime.datetime(2024, 1, 18, 23, 49, 8, 922470, tzinfo=datetime.timezone.utc), 'rating_count': 7, 'rating_avg': Decimal('2.71')}
# {'id': 22319, 'title': 'Trouble the Water', 'overview': '"Trouble the Water" takes you inside Hurricane Katrina in a way never before seen on screen. The film opens the day before the storm makes landfall--just blocks away from the French Quarter but far from the New Orleans that most tourists knew. Kimberly Rivers Roberts, an aspiring rap artist, is turning her new video camera on herself and her Ninth Ward neighbors trapped in the city. Weaving an insider\'s view of Katrina with a mix of verité and in-your-face filmmaking, it is a redemptive tale of self-described street hustlers who become heroes--two unforgettable people who survive the storm and then seize a chance for a new beginning.', 'release_date': datetime.date(2008, 1, 20), 'rating_last_updated': datetime.datetime(2024, 1, 18, 23, 49, 8, 924937, tzinfo=datetime.timezone.utc), 'rating_count': 9, 'rating_avg': Decimal('2.78')}
# {'id': 61357, 'title': 'Trouble the Water', 'overview': '"Trouble the Water" takes you inside Hurricane Katrina in a way never before seen on screen. The film opens the day before the storm makes landfall--just blocks away from the French Quarter but far from the New Orleans that most tourists knew. Kimberly Rivers Roberts, an aspiring rap artist, is turning her new video camera on herself and her Ninth Ward neighbors trapped in the city. Weaving an insider\'s view of Katrina with a mix of verité and in-your-face filmmaking, it is a redemptive tale of self-described street hustlers who become heroes--two unforgettable people who survive the storm and then seize a chance for a new beginning.', 'release_date': datetime.date(2008, 1, 20), 'rating_last_updated': datetime.datetime(2024, 1, 18, 23, 49, 8, 924937, tzinfo=datetime.timezone.utc), 'rating_count': 9, 'rating_avg': Decimal('2.78')}
# {'id': 22327, 'title': 'Youth in Revolt', 'overview': 'Nick Twisp (Michael Cera), a teen with a taste for the finer things in life like Sinatra and Fellini, falls hopelessly in love with the beautiful, free-spirited Sheeni Saunders (Portia Doubleday) while on a family vacation.  But family, geography and jealous ex-lovers conspire to keep these two apart. Nick abandons his dull, predictable life and develops a rebellious alter ego: François.  With his ascot, his moustache and his cigarette, François will stop at nothing to be with Sheeni, and leads Nick on a path of destruction with unpredictable consequences..', 'release_date': datetime.date(2009, 9, 11), 'rating_last_updated': datetime.datetime(2024, 1, 18, 23, 49, 8, 931778, tzinfo=datetime.timezone.utc), 'rating_count': 13, 'rating_avg': Decimal('2.92')}
# {'id': 73266, 'title': 'Youth in Revolt', 'overview': 'Nick Twisp (Michael Cera), a teen with a taste for the finer things in life like Sinatra and Fellini, falls hopelessly in love with the beautiful, free-spirited Sheeni Saunders (Portia Doubleday) while on a family vacation.  But family, geography and jealous ex-lovers conspire to keep these two apart. Nick abandons his dull, predictable life and develops a rebellious alter ego: François.  With his ascot, his moustache and his cigarette, François will stop at nothing to be with Sheeni, and leads Nick on a path of destruction with unpredictable consequences..', 'release_date': datetime.date(2009, 9, 11), 'rating_last_updated': datetime.datetime(2024, 1, 18, 23, 49, 8, 931778, tzinfo=datetime.timezone.utc), 'rating_count': 13, 'rating_avg': Decimal('2.92')}
# {'id': 22342, 'title': 'The Big Combo', 'overview': "Police Lt. Leonard Diamond vies to bring a clever, well connected, and sadistic gangster to justice all the while obsessing over the gangsters' girlfriend.", 'release_date': datetime.date(1955, 2, 15), 'rating_last_updated': datetime.datetime(2024, 1, 18, 23, 49, 8, 940920, tzinfo=datetime.timezone.utc), 'rating_count': 12, 'rating_avg': Decimal('3.50')}
# {'id': 3292, 'title': 'The Big Combo', 'overview': "Police Lt. Leonard Diamond vies to bring a clever, well connected, and sadistic gangster to justice all the while obsessing over the gangsters' girlfriend.", 'release_date': datetime.date(1955, 2, 15), 'rating_last_updated': datetime.datetime(2024, 1, 18, 23, 49, 8, 940920, tzinfo=datetime.timezone.utc), 'rating_count': 12, 'rating_avg': Decimal('3.50')}
# {'id': 22345, 'title': 'Baby Geniuses', 'overview': 'Scientist hold talking, super-intelligent babies captive, but things take a turn for the worse when a mix-up occurs between a baby genius and its twin.', 'release_date': datetime.date(1999, 3, 12), 'rating_last_updated': datetime.datetime(2024, 1, 18, 23, 49, 8, 942996, tzinfo=datetime.timezone.utc), 'rating_count': 8, 'rating_avg': Decimal('3.00')}
# {'id': 2555, 'title': 'Baby Geniuses', 'overview': 'Scientist hold talking, super-intelligent babies captive, but things take a turn for the worse when a mix-up occurs between a baby genius and its twin.', 'release_date': datetime.date(1999, 3, 12), 'rating_last_updated': datetime.datetime(2024, 1, 18, 23, 49, 8, 942996, tzinfo=datetime.timezone.utc), 'rating_count': 8, 'rating_avg': Decimal('3.00')}
# {'id': 22377, 'title': 'The Green Berets', 'overview': 'Col. Mike Kirby picks two teams of crack Green Berets for a mission in South Vietnam. First off is to build and control a camp that is trying to be taken by the enemy the second mission is to kidnap a North Vietnamese General', 'release_date': datetime.date(1968, 7, 4), 'rating_last_updated': datetime.datetime(2024, 1, 18, 23, 49, 8, 955364, tzinfo=datetime.timezone.utc), 'rating_count': 6, 'rating_avg': Decimal('3.33')}
# {'id': 32174, 'title': 'The Green Berets', 'overview': 'Col. Mike Kirby picks two teams of crack Green Berets for a mission in South Vietnam. First off is to build and control a camp that is trying to be taken by the enemy the second mission is to kidnap a North Vietnamese General', 'release_date': datetime.date(1968, 7, 4), 'rating_last_updated': datetime.datetime(2024, 1, 18, 23, 49, 8, 955364, tzinfo=datetime.timezone.utc), 'rating_count': 6, 'rating_avg': Decimal('3.33')}

# %%
from ratings.tasks import task_update_movie_ratings
task_update_movie_ratings()
